# %%
pip install vaderSentiment
# Out:
# Requirement already satisfied: vaderSentiment in /Users/joakimlarsen/opt/anaconda3/lib/python3.9/site-packages (3.3.2)
# Requirement already satisfied: requests in /Users/joakimlarsen/opt/anaconda3/lib/python3.9/site-packages (from vaderSentiment) (2.26.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/joakimlarsen/opt/anaconda3/lib/python3.9/site-packages (from requests->vaderSentiment) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/joakimlarsen/opt/anaconda3/lib/python3.9/site-packages (from requests->vaderSentiment) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/joakimlarsen/opt/anaconda3/lib/python3.9/site-packages (from requests->vaderSentiment) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/joakimlarsen/opt/anaconda3/lib/python3.9/site-packages (from requests->vaderSentiment) (1.26.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from textblob import TextBlob
import re
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
TeslaR = pd.read_csv("BareTesla.csv")

# %%
TeslaR.shape
# Out:
# (9414, 13)

# %%
TeslaAksje = pd.read_csv("TeslaLabelFinal1.csv")

# %%
#Merge datasettene
merge = TeslaR.merge(TeslaAksje, how = "inner", on = "Date")

# %%
#Create a function to get the subjecticity
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

#Create a fuction to get the polarity
def getPolarity(text):
    return TextBlob(text).sentiment.polarity

# %%
#Create two new columns "Subjectivity" and "Polarity"
merge["Subjectivity"] = merge["article_content"].apply(getSubjectivity)
merge["Polarity"] = merge["article_content"].apply(getPolarity)

# %%
merge["article_content"] = merge["article_content"].str.lower()

# %%
import nltk

from nltk.corpus import stopwords
stop = stopwords.words('english')

# %%
merge['article_content_without_stopwords'] = merge['article_content'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))

# %%
from nltk.stem import PorterStemmer

port = PorterStemmer()

# %%
def stem_words(article_content_without_stopwords):
    return " ".join([port.stem(word) for word in article_content_without_stopwords.split()])

merge["EtterStemming"] = merge["article_content_without_stopwords"].apply(lambda article_content_without_stopwords: stem_words(article_content_without_stopwords))
merge.head()
# Out:
#    Unnamed: 0        Date     X                                  X_id  \
# 0           1  2018-03-13    62  {'$oid': '5ab8cb373efc2c03c520c0cb'}
# 1           2  2018-03-13   370  {'$oid': '5ab8d0e43efc2c03c520cd51'}
# 2           4  2018-03-13   787  {'$oid': '5ab8d5ed3efc2c03c520d8a7'}
# 3           5  2018-03-13   793  {'$oid': '5ab8d61e3efc2c03c520d915'}
# 4           9  2018-03-13  1113  {'$oid': '5ab8d62a3efc2c03c520d933'}
#
#                                         article_link  \
# 0  https://www.nasdaq.com/article/can-tesla-inc-h...
# 1  https://www.nasdaq.com/article/6-energy-stocks...
# 2  https://www.nasdaq.com/article/why-we-might-be...
# 3  https://www.nasdaq.com/article/nasdaq-streak-s...
# 4  https://www.nasdaq.com/article/tesla-bulls-bew...
#
#                                        article_title  \
# 0  Can Tesla, Inc. Hit Its Model 3 Production Tar...
# 1             6 Energy Stocks I'd Avoid at All Costs
# 2            Why We Might Be Hitting Peak Smartphone
# 3  Nasdaq Streak Snapped on Tech Pullback, White ...
# 4  Tesla Bulls Beware: Volkswagen Wants to Be the...
#
#                         article_time  \
# 0  {'$date': '2018-03-13T11:05:00Z'}
# 1  {'$date': '2018-03-13T06:05:00Z'}
# 2  {'$date': '2018-03-13T16:48:13Z'}
# 3  {'$date': '2018-03-13T16:26:43Z'}
# 4  {'$date': '2018-03-13T16:20:00Z'}
#
#                                     author_name  \
# 0                 By Daniel Sparks, Motley Fool
# 1                  By Travis Hoium, Motley Fool
# 2                    By Chris Hill, Motley Fool
# 3  By pmartin@sir-inc.com, Schaeffer's Research
# 4                  By Benjamin Rains, Zacks.com
#
#                                 author_link  \
# 0        https://www.nasdaq.com/author/fool
# 1        https://www.nasdaq.com/author/fool
# 2        https://www.nasdaq.com/author/fool
# 3  https://www.nasdaq.com/author/schaeffers
# 4       https://www.nasdaq.com/author/zacks
#
#                                      article_content  ...        Low  \
# 0  with just a few weeks left in tesla's (nasdaq:...  ...  65.300003
# 1  the energy industry has been one of the most s...  ...  65.300003
# 2  in to this episode ofmarketfoolery , analyst s...  ...  65.300003
# 3  stocks once again started the day off strong, ...  ...  65.300003
# 4  german automotive giant volkswagen vlkaydetail...  ...  65.300003
#
#        Close    Volume  Dividends  Stock Splits  Label  Subjectivity  \
# 0  68.367996  29829000          0           0.0      1      0.513533
# 1  68.367996  29829000          0           0.0      1      0.512743
# 2  68.367996  29829000          0           0.0      1      0.499273
# 3  68.367996  29829000          0           0.0      1      0.463206
# 4  68.367996  29829000          0           0.0      1      0.435281
#
#    Polarity                  article_content_without_stopwords  \
# 0  0.184208  weeks left tesla's (nasdaq: tsla) first quarte...
# 1  0.221662  energy industry one stable investors last cent...
# 2  0.135207  episode ofmarketfoolery , analyst simon ericks...
# 3 -0.015142  stocks started day strong, thanks encouragingi...
# 4  0.023066  german automotive giant volkswagen vlkaydetail...
#
#                                        EtterStemming
# 0  week left tesla' (nasdaq: tsla) first quarter,...
# 1  energi industri one stabl investor last centur...
# 2  episod ofmarketfooleri , analyst simon erickso...
# 3  stock start day strong, thank encouraginginfl ...
# 4  german automot giant volkswagen vlkaydetail pl...
#
# [5 rows x 25 columns]

# %%
#Create a function to get the sentiment scores
def getSIA(EtterStemming):
    sia = SentimentIntensityAnalyzer()
    sentiment = sia.polarity_scores(EtterStemming)
    return sentiment

# %%
#Get the sentiment scores for each day
compound = []
neg = []
pos = []
neu = []
SIA = 0

for i in range(0, len(merge["EtterStemming"])):
    SIA = getSIA(merge["EtterStemming"][i])
    compound.append(SIA["compound"])
    neg.append(SIA["neg"])
    neu.append(SIA["neu"])
    pos.append(SIA["pos"])

# %%
#Store the sentiment scores in the merge data set:
merge["Compound"] = compound
merge["Negative"] = neg
merge["Neutral"] = neu
merge["Positive"] = pos

# %%
#Show the merge data
merge.head(3)
# Out:
#    Unnamed: 0        Date    X                                  X_id  \
# 0           1  2018-03-13   62  {'$oid': '5ab8cb373efc2c03c520c0cb'}
# 1           2  2018-03-13  370  {'$oid': '5ab8d0e43efc2c03c520cd51'}
# 2           4  2018-03-13  787  {'$oid': '5ab8d5ed3efc2c03c520d8a7'}
#
#                                         article_link  \
# 0  https://www.nasdaq.com/article/can-tesla-inc-h...
# 1  https://www.nasdaq.com/article/6-energy-stocks...
# 2  https://www.nasdaq.com/article/why-we-might-be...
#
#                                        article_title  \
# 0  Can Tesla, Inc. Hit Its Model 3 Production Tar...
# 1             6 Energy Stocks I'd Avoid at All Costs
# 2            Why We Might Be Hitting Peak Smartphone
#
#                         article_time                    author_name  \
# 0  {'$date': '2018-03-13T11:05:00Z'}  By Daniel Sparks, Motley Fool
# 1  {'$date': '2018-03-13T06:05:00Z'}   By Travis Hoium, Motley Fool
# 2  {'$date': '2018-03-13T16:48:13Z'}     By Chris Hill, Motley Fool
#
#                           author_link  \
# 0  https://www.nasdaq.com/author/fool
# 1  https://www.nasdaq.com/author/fool
# 2  https://www.nasdaq.com/author/fool
#
#                                      article_content  ... Stock Splits Label  \
# 0  with just a few weeks left in tesla's (nasdaq:...  ...          0.0     1
# 1  the energy industry has been one of the most s...  ...          0.0     1
# 2  in to this episode ofmarketfoolery , analyst s...  ...          0.0     1
#
#   Subjectivity  Polarity                  article_content_without_stopwords  \
# 0     0.513533  0.184208  weeks left tesla's (nasdaq: tsla) first quarte...
# 1     0.512743  0.221662  energy industry one stable investors last cent...
# 2     0.499273  0.135207  episode ofmarketfoolery , analyst simon ericks...
#
#                                        EtterStemming  Compound  Negative  \
# 0  week left tesla' (nasdaq: tsla) first quarter,...    0.9440     0.044
# 1  energi industri one stabl investor last centur...    0.9851     0.074
# 2  episod ofmarketfooleri , analyst simon erickso...    0.9997     0.036
#
#    Neutral  Positive
# 0    0.876     0.080
# 1    0.808     0.119
# 2    0.800     0.164
#
# [3 rows x 29 columns]

# %%
#Create a list of column to keep
keep_columns = ["Open", "Low", "High", "Volume", "Subjectivity", "Polarity", "Compound", "Negative", "Neutral", "Positive", "Label"]
df = merge[keep_columns]
df
# Out:
#            Open        Low       High    Volume  Subjectivity  Polarity  \
# 0     65.722000  65.300003  69.442001  29829000      0.513533  0.184208
# 1     65.722000  65.300003  69.442001  29829000      0.512743  0.221662
# 2     65.722000  65.300003  69.442001  29829000      0.499273  0.135207
# 3     65.722000  65.300003  69.442001  29829000      0.463206 -0.015142
# 4     65.722000  65.300003  69.442001  29829000      0.435281  0.023066
# ...         ...        ...        ...       ...           ...       ...
# 8672  43.147999  42.405998  43.759998  27081000      0.511702  0.085723
# 8673  43.147999  42.405998  43.759998  27081000      0.540350  0.054140
# 8674  43.147999  42.405998  43.759998  27081000      0.454072  0.102247
# 8675  43.147999  42.405998  43.759998  27081000      0.469294  0.179761
# 8676  43.147999  42.405998  43.759998  27081000      0.446468  0.129609
#
#       Compound  Negative  Neutral  Positive  Label
# 0       0.9440     0.044    0.876     0.080      1
# 1       0.9851     0.074    0.808     0.119      1
# 2       0.9997     0.036    0.800     0.164      1
# 3       0.8402     0.064    0.845     0.091      1
# 4       0.9627     0.005    0.933     0.061      1
# ...        ...       ...      ...       ...    ...
# 8672    0.9337     0.066    0.836     0.098      0
# 8673   -0.9693     0.125    0.793     0.082      0
# 8674    0.9992     0.030    0.878     0.093      0
# 8675    0.9766     0.059    0.838     0.104      0
# 8676    0.9764     0.043    0.864     0.093      0
#
# [8677 rows x 11 columns]

# %%
#Create the feature data set
X = df
X = np.array(X.drop(["Label"], 1))

#Create the target data set
y = np.array(df["Label"])
# Out:
# /var/folders/m7/01kjn8yx6d3_tjkcr1dkd9g80000gn/T/ipykernel_27374/988765945.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X = np.array(X.drop(["Label"], 1))

# %%
#Split the data into 80% trainig and 20% testing data set
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
#Create and train the model
model = LinearDiscriminantAnalysis().fit(x_train, y_train)

# %%
#Show the models predictions
predictions = model.predict(x_test)
predictions
# Out:
# array([1, 0, 1, ..., 1, 1, 1])

# %%
y_test
# Out:
# array([1, 0, 1, ..., 1, 1, 1])

# %%
#Show the model metrics
print( classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.85      0.86       922
#            1       0.84      0.84      0.84       814
#
#     accuracy                           0.85      1736
#    macro avg       0.85      0.85      0.85      1736
# weighted avg       0.85      0.85      0.85      1736
